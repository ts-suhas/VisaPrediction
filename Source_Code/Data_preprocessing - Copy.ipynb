# %%
#import required library packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#create dataframe with dataset
visa_candidates = pd.read_csv(r'C:\project\visa_candidates.csv')

# %%
#print the first few rows of dataframe
visa_candidates.head()
# Out:
#    id                      name  gre_score toefl_score  university_rating  \
# 0   1       Alluri Udgith Reddy        337         118                  4
# 1   2        Annem Naga Sujitha        324         107                  4
# 2   3         Borra Kiran Kumar        316         104                  3
# 3   4  Dadisetti V. S. Rajkumar        322         110                  3
# 4   5       Dasari Sai Rishitha        314         103                  2
#
#    sop  lor  cgpa  research  no_of_backlogs relevant_study  year_gaps  \
# 0  4.5  4.5  9.65         1               0            YES          0
# 1  4.0  4.5  8.87         1               0            YES          0
# 2  3.0  3.5  8.00         1               0            YES          0
# 3  3.5  2.5  8.67         1               0            YES          0
# 4  2.0  3.0  8.21         0               3            YES          0
#
#    parents_annual_income  no_of_times_rejected us_relatives  work_experience  \
# 0              1690680.0                     0           NO                1
# 1              1207915.0                     0           NO                0
# 2              1761149.0                     0           NO                4
# 3              1983861.0                     0           NO                3
# 4               588408.0                     0           NO                0
#
#    criminal_records  chance_of_visa_approval
# 0                 0                     0.92
# 1                 0                     0.76
# 2                 0                     0.72
# 3                 0                     0.80
# 4                 0                     0.65

# %%
#print last rows of dataframe
visa_candidates.tail()
# Out:
#       id                              name  gre_score toefl_score  \
# 404  127                  Namrata Sira Rao        323         113
# 405  128  Oruganti Chakradhar Prabal Kumar        319         112
# 406  129                Parnem Rahul Reddy        326         112
# 407  130                  Peddi Sai Pankaj        333         118
# 408  131               Potluri Sai Cherish        339         114
#
#      university_rating  sop  lor  cgpa  research  no_of_backlogs  \
# 404                  3  4.0  3.0  9.32         1               0
# 405                  3  2.5  2.0  8.71         1               1
# 406                  3  3.5  3.0  9.10         1               0
# 407                  5  5.0  5.0  9.35         1               0
# 408                  5  4.0  4.5  9.76         1               0
#
#     relevant_study  year_gaps  parents_annual_income  no_of_times_rejected  \
# 404            YES          0              2792053.0                     0
# 405            YES          0              1947922.0                     0
# 406            YES          0              1239769.0                     0
# 407            YES          0              2563093.0                     0
# 408            YES          0              1352725.0                     0
#
#     us_relatives  work_experience  criminal_records  chance_of_visa_approval
# 404           NO                4                 0                     0.85
# 405          YES                4                 0                     0.78
# 406           NO                0                 0                     0.84
# 407           NO                5                 0                     0.92
# 408           NO                4                 0                     0.96

# %%
#print the basic information of the dataframe
visa_candidates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 409 entries, 0 to 408
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       409 non-null    int64
#  1   name                     409 non-null    object
#  2   gre_score                409 non-null    int64
#  3   toefl_score              409 non-null    object
#  4   university_rating        409 non-null    int64
#  5   sop                      409 non-null    float64
#  6   lor                      409 non-null    float64
#  7   cgpa                     407 non-null    float64
#  8   research                 409 non-null    int64
#  9   no_of_backlogs           409 non-null    int64
#  10  relevant_study           406 non-null    object
#  11  year_gaps                409 non-null    int64
#  12  parents_annual_income    407 non-null    float64
#  13  no_of_times_rejected     409 non-null    int64
#  14  us_relatives             405 non-null    object
#  15  work_experience          409 non-null    int64
#  16  criminal_records         409 non-null    int64
#  17  chance_of_visa_approval  409 non-null    float64
# dtypes: float64(5), int64(9), object(4)
# memory usage: 57.6+ KB

# %%
#output basic stats of the dataframe
visa_candidates.describe()
# Out:
#                id   gre_score  university_rating         sop         lor  \
# count  409.000000  409.000000         409.000000  409.000000  409.000000
# mean   199.454768  317.031785           3.110024    3.409535    3.455990
# std    115.137209   11.514546           1.146231    1.008120    0.903028
# min      1.000000  290.000000           1.000000    1.000000    1.000000
# 25%    101.000000  309.000000           2.000000    2.500000    3.000000
# 50%    198.000000  317.000000           3.000000    3.500000    3.500000
# 75%    299.000000  325.000000           4.000000    4.000000    4.000000
# max    400.000000  340.000000           5.000000    5.000000    5.000000
#
#              cgpa    research  no_of_backlogs   year_gaps  \
# count  407.000000  409.000000      409.000000  409.000000
# mean     8.610737    0.552567        1.838631    0.141809
# std      0.601022    0.497838        2.005721    0.442184
# min      6.800000    0.000000        0.000000    0.000000
# 25%      8.175000    0.000000        0.000000    0.000000
# 50%      8.640000    1.000000        2.000000    0.000000
# 75%      9.090000    1.000000        3.000000    0.000000
# max      9.920000    1.000000        9.000000    2.000000
#
#        parents_annual_income  no_of_times_rejected  work_experience  \
# count           4.070000e+02            409.000000       409.000000
# mean            1.688082e+06              0.188264         2.535452
# std             7.745468e+05              0.595127         1.716226
# min             4.000340e+05              0.000000         0.000000
# 25%             9.683195e+05              0.000000         1.000000
# 50%             1.709228e+06              0.000000         3.000000
# 75%             2.376814e+06              0.000000         4.000000
# max             2.975122e+06              4.000000         5.000000
#
#        criminal_records  chance_of_visa_approval
# count        409.000000               409.000000
# mean           0.029340                 0.726601
# std            0.182896                 0.142983
# min            0.000000                 0.340000
# 25%            0.000000                 0.640000
# 50%            0.000000                 0.730000
# 75%            0.000000                 0.840000
# max            2.000000                 0.970000

# %%
#check for null values in dataframe
visa_candidates.isna().sum()
# Out:
# id                         0
# name                       0
# gre_score                  0
# toefl_score                0
# university_rating          0
# sop                        0
# lor                        0
# cgpa                       2
# research                   0
# no_of_backlogs             0
# relevant_study             3
# year_gaps                  0
# parents_annual_income      2
# no_of_times_rejected       0
# us_relatives               4
# work_experience            0
# criminal_records           0
# chance_of_visa_approval    0
# dtype: int64

# %%
#remove the rows containing null values
visa_candidates.dropna(inplace=True)

# %%
#check for null values again
visa_candidates.isna().sum()
# Out:
# id                         0
# name                       0
# gre_score                  0
# toefl_score                0
# university_rating          0
# sop                        0
# lor                        0
# cgpa                       0
# research                   0
# no_of_backlogs             0
# relevant_study             0
# year_gaps                  0
# parents_annual_income      0
# no_of_times_rejected       0
# us_relatives               0
# work_experience            0
# criminal_records           0
# chance_of_visa_approval    0
# dtype: int64

# %%
#check for duplicated rows
visa_candidates[visa_candidates.duplicated('name')]
# Out:
#       id                              name  gre_score toefl_score  \
# 400   84                 Jaswanth Talasila        322         115
# 401  327       Vedula Sri Bala Sai Deepthi        299         100
# 402  254                          P Anusha        335         115
# 404  127                  Namrata Sira Rao        323         113
# 405  128  Oruganti Chakradhar Prabal Kumar        319         112
# 406  129                Parnem Rahul Reddy        326         112
# 407  130                  Peddi Sai Pankaj        333         118
# 408  131               Potluri Sai Cherish        339         114
#
#      university_rating  sop  lor  cgpa  research  no_of_backlogs  \
# 400                  5  4.0  4.5  9.36         1               0
# 401                  3  2.0  2.0  8.02         0               3
# 402                  4  4.5  4.5  9.68         1               0
# 404                  3  4.0  3.0  9.32         1               0
# 405                  3  2.5  2.0  8.71         1               1
# 406                  3  3.5  3.0  9.10         1               0
# 407                  5  5.0  5.0  9.35         1               0
# 408                  5  4.0  4.5  9.76         1               0
#
#     relevant_study  year_gaps  parents_annual_income  no_of_times_rejected  \
# 400            YES          0              1709228.0                     0
# 401             NO          0              1644473.0                     1
# 402            YES          0              2663024.0                     0
# 404            YES          0              2792053.0                     0
# 405            YES          0              1947922.0                     0
# 406            YES          0              1239769.0                     0
# 407            YES          0              2563093.0                     0
# 408            YES          0              1352725.0                     0
#
#     us_relatives  work_experience  criminal_records  chance_of_visa_approval
# 400           NO                3                 0                     0.92
# 401          YES                5                 0                     0.63
# 402           NO                2                 0                     0.93
# 404           NO                4                 0                     0.85
# 405          YES                4                 0                     0.78
# 406           NO                0                 0                     0.84
# 407           NO                5                 0                     0.92
# 408           NO                4                 0                     0.96

# %%
#drop the diplicate rows
visa_candidates.drop_duplicates(keep='first',inplace=True)

# %%
#check for the suplicate rows again
visa_candidates[visa_candidates.duplicated('name')]
# Out:
# Empty DataFrame
# Columns: [id, name, gre_score, toefl_score, university_rating, sop, lor, cgpa, research, no_of_backlogs, relevant_study, year_gaps, parents_annual_income, no_of_times_rejected, us_relatives, work_experience, criminal_records, chance_of_visa_approval]
# Index: []

# %%
#find correlation between the columns
visa_candidates.corr()
# Out:
#                                id  gre_score  university_rating       sop  \
# id                       1.000000  -0.098286          -0.168640 -0.169451
# gre_score               -0.098286   1.000000           0.668404  0.613669
# university_rating       -0.168640   0.668404           1.000000  0.737968
# sop                     -0.169451   0.613669           0.737968  1.000000
# lor                     -0.094936   0.564859           0.667689  0.735642
# cgpa                    -0.046355   0.832868           0.741798  0.718538
# research                -0.053978   0.586148           0.438488  0.441445
# no_of_backlogs           0.028724  -0.628810          -0.546995 -0.513921
# year_gaps               -0.294708  -0.303685          -0.260961 -0.191298
# parents_annual_income    0.002783  -0.000362           0.058966  0.026969
# no_of_times_rejected     0.303645  -0.336154          -0.368355 -0.456494
# work_experience          0.113001   0.049793           0.007088  0.030321
# criminal_records        -0.031114  -0.208823          -0.132884 -0.120250
# chance_of_visa_approval  0.041048   0.802802           0.705293  0.670841
#
#                               lor      cgpa  research  no_of_backlogs  \
# id                      -0.094936 -0.046355 -0.053978        0.028724
# gre_score                0.564859  0.832868  0.586148       -0.628810
# university_rating        0.667689  0.741798  0.438488       -0.546995
# sop                      0.735642  0.718538  0.441445       -0.513921
# lor                      1.000000  0.670178  0.412030       -0.475076
# cgpa                     0.670178  1.000000  0.532531       -0.673097
# research                 0.412030  0.532531  1.000000       -0.508186
# no_of_backlogs          -0.475076 -0.673097 -0.508186        1.000000
# year_gaps               -0.248319 -0.384862 -0.148423        0.515076
# parents_annual_income   -0.012421  0.039072 -0.059527       -0.006656
# no_of_times_rejected    -0.388800 -0.393622 -0.290834        0.318997
# work_experience         -0.063600  0.052939  0.089619       -0.047744
# criminal_records        -0.182403 -0.250473 -0.127275        0.418635
# chance_of_visa_approval  0.670068  0.876633  0.558113       -0.774150
#
#                          year_gaps  parents_annual_income  \
# id                       -0.294708               0.002783
# gre_score                -0.303685              -0.000362
# university_rating        -0.260961               0.058966
# sop                      -0.191298               0.026969
# lor                      -0.248319              -0.012421
# cgpa                     -0.384862               0.039072
# research                 -0.148423              -0.059527
# no_of_backlogs            0.515076              -0.006656
# year_gaps                 1.000000              -0.009062
# parents_annual_income    -0.009062               1.000000
# no_of_times_rejected      0.070598               0.080230
# work_experience          -0.084975               0.003466
# criminal_records          0.407290               0.080757
# chance_of_visa_approval  -0.550647               0.015606
#
#                          no_of_times_rejected  work_experience  \
# id                                   0.303645         0.113001
# gre_score                           -0.336154         0.049793
# university_rating                   -0.368355         0.007088
# sop                                 -0.456494         0.030321
# lor                                 -0.388800        -0.063600
# cgpa                                -0.393622         0.052939
# research                            -0.290834         0.089619
# no_of_backlogs                       0.318997        -0.047744
# year_gaps                            0.070598        -0.084975
# parents_annual_income                0.080230         0.003466
# no_of_times_rejected                 1.000000         0.029994
# work_experience                      0.029994         1.000000
# criminal_records                     0.176819        -0.028054
# chance_of_visa_approval             -0.425876         0.055930
#
#                          criminal_records  chance_of_visa_approval
# id                              -0.031114                 0.041048
# gre_score                       -0.208823                 0.802802
# university_rating               -0.132884                 0.705293
# sop                             -0.120250                 0.670841
# lor                             -0.182403                 0.670068
# cgpa                            -0.250473                 0.876633
# research                        -0.127275                 0.558113
# no_of_backlogs                   0.418635                -0.774150
# year_gaps                        0.407290                -0.550647
# parents_annual_income            0.080757                 0.015606
# no_of_times_rejected             0.176819                -0.425876
# work_experience                 -0.028054                 0.055930
# criminal_records                 1.000000                -0.394265
# chance_of_visa_approval         -0.394265                 1.000000

# %%
#scatter plot of gre_score vs chance_of_visa-approval
visa_candidates.plot.scatter(x="gre_score",y="chance_of_visa_approval")
# Out:
# <AxesSubplot:xlabel='gre_score', ylabel='chance_of_visa_approval'>

# %%
#scatter plot of cgpa vs chance_of_visa-approval
visa_candidates.plot.scatter(x="cgpa",y="chance_of_visa_approval")
# Out:
# <AxesSubplot:xlabel='cgpa', ylabel='chance_of_visa_approval'>

# %%
#scatter plot of university_rating vs chance_of_visa-approval
visa_candidates.plot.scatter(x="university_rating",y="chance_of_visa_approval")
# Out:
# <AxesSubplot:xlabel='university_rating', ylabel='chance_of_visa_approval'>

# %%
#scatter plot of no_of_backlogs vs chance_of_visa-approval
visa_candidates.plot.scatter(x="no_of_backlogs",y="chance_of_visa_approval")
# Out:
# <AxesSubplot:xlabel='no_of_backlogs', ylabel='chance_of_visa_approval'>

# %%
#scatter plot of year_gaps vs chance_of_visa-approval
visa_candidates.plot.scatter(x="year_gaps",y="chance_of_visa_approval")
# Out:
# <AxesSubplot:xlabel='year_gaps', ylabel='chance_of_visa_approval'>

# %%
#extract the yes/no values as 1/0 values respectively
mymap={'NO':0,'YES':1}
visa_candidates=visa_candidates.applymap(lambda s:mymap.get(s) if s in mymap else s)

# %%
#check if yes/no values are mapped to 1/0
visa_candidates.head()
# Out:
#    id                      name  gre_score toefl_score  university_rating  \
# 0   1       Alluri Udgith Reddy        337         118                  4
# 1   2        Annem Naga Sujitha        324         107                  4
# 2   3         Borra Kiran Kumar        316         104                  3
# 3   4  Dadisetti V. S. Rajkumar        322         110                  3
# 4   5       Dasari Sai Rishitha        314         103                  2
#
#    sop  lor  cgpa  research  no_of_backlogs  relevant_study  year_gaps  \
# 0  4.5  4.5  9.65         1               0               1          0
# 1  4.0  4.5  8.87         1               0               1          0
# 2  3.0  3.5  8.00         1               0               1          0
# 3  3.5  2.5  8.67         1               0               1          0
# 4  2.0  3.0  8.21         0               3               1          0
#
#    parents_annual_income  no_of_times_rejected  us_relatives  work_experience  \
# 0              1690680.0                     0             0                1
# 1              1207915.0                     0             0                0
# 2              1761149.0                     0             0                4
# 3              1983861.0                     0             0                3
# 4               588408.0                     0             0                0
#
#    criminal_records  chance_of_visa_approval
# 0                 0                     0.92
# 1                 0                     0.76
# 2                 0                     0.72
# 3                 0                     0.80
# 4                 0                     0.65
